left_top_top_thigh =  [(189.26689976689977, 436.7960372960374), (212.76340326340323, 465.51398601398614), (232.34382284382275, 513.8123543123544), (225.81701631701628, 526.8659673659674), (215.37412587412587, 500.75874125874134), (203.62587412587413, 469.4300699300701), (189.26689976689977, 436.7960372960374), (189.26689976689977, 436.7960372960374), (189.26689976689977, 436.7960372960374), (189.26689976689977, 436.7960372960374), (189.26689976689977, 436.7960372960374), (189.26689976689977, 436.7960372960374)]
left_mid_long_thigh = [(185.35081585081582, 444.6282051282052), (211.45804195804192, 547.7517482517484), (223.20629370629365, 602.5769230769232), (227.1223776223776, 579.0804195804196), (221.90093240093233, 542.5303030303031), (210.1526806526806, 505.9801864801866), (185.35081585081582, 445.9335664335665), (185.35081585081582, 445.9335664335665), (185.35081585081582, 445.9335664335665), (185.35081585081582, 445.9335664335665), (185.35081585081582, 445.9335664335665), (185.35081585081582, 445.9335664335665)]
left_big_mid_thigh = [(178.82400932400935, 451.1550116550118), (167.07575757575762, 487.7051282051283), (168.38111888111882, 532.0874125874127), (186.65617715617714, 605.1876456876457), (198.40442890442887, 629.9895104895106), (204.93123543123545, 618.2412587412589), (207.54195804195808, 586.9125874125875), (207.54195804195808, 554.2785547785548), (202.32051282051282, 525.5606060606061), (194.48834498834492, 490.3158508158509), (185.35081585081582, 469.4300699300701), (181.43473193473187, 453.7657342657344)]
left_low_left_thigh = [(163.15967365967367, 534.6981351981353), (164.465034965035, 571.2482517482518), (173.6025641025641, 607.7983682983684), (180.12937062937067, 628.6841491841492), (186.65617715617714, 636.5163170163171), (187.96153846153845, 626.0734265734267), (186.65617715617714, 611.7144522144523), (177.51864801864804, 594.7447552447553), (170.99184149184146, 563.4160839160841), (165.7703962703963, 542.5303030303031), (165.7703962703963, 534.6981351981353), (163.15967365967367, 534.6981351981353)]
left_low_right_thigh = [(210.1526806526806, 566.0268065268066), (211.45804195804192, 596.0501165501166), (206.23659673659677, 627.378787878788), (211.45804195804192, 639.1270396270397), (216.67948717948718, 639.1270396270397), (219.29020979020981, 631.2948717948718), (220.59557109557113, 607.7983682983684), (216.67948717948718, 582.9965034965036), (212.76340326340323, 571.2482517482518), (210.1526806526806, 566.0268065268066), (211.45804195804192, 568.6375291375292), (211.45804195804192, 568.6375291375292)]


coordinates_list = [left_chest, right_chest, 
                left_top_trunk, left_mid_top_trunk, left_mid_low_trunk, left_low_trunk,
                right_top_trunk, right_mid_top_trunk, right_mid_low_trunk, right_low_trunk,
                left_front_shoulder, left_left_biceps, left_right_biceps,
                left_top_low_thigh, left_top_top_thigh, left_mid_long_thigh, left_big_mid_thigh, left_low_left_thigh, left_low_right_thigh,
                left_top_forearm, left_mid_forearm, left_low_forearm,
                right_front_shoulder,right_right_biceps, right_left_biceps,
                right_top_forearm, right_mid_forearm, right_low_forearm,
                right_top_low_thigh, right_top_top_thigh, right_mid_long_thigh, right_big_mid_thigh, right_low_left_thigh, right_low_right_thigh]
# Load the image
image = Image.open(image_path)

# Create a draw object
draw = ImageDraw.Draw(image)
for cords in coordinates_list:
    # Convert coordinates to integer tuples
    polygon_coords = [(int(x), int(y)) for x, y in cords]


    fill_color = (200, 0, 0, 128)  # 128 is 50% transparency (255 is fully opaque, 0 is fully transparent)
    # Draw the polygon with specified fill and outline colors
    draw.polygon(polygon_coords, outline='red', fill=fill_color)


# Save or display the image
image.save(output_image_path)
image.show()

# %%
primary = ['klatka']
secondary = ['brzuch', 'nogi']

# %%
body_dict = {'klatka': [left_chest, right_chest],
             'brzuch':  [left_top_trunk, left_mid_top_trunk, left_mid_low_trunk, left_low_trunk, right_top_trunk, right_mid_top_trunk, right_mid_low_trunk, right_low_trunk,],
             'nogi': [right_top_low_thigh, right_top_top_thigh, right_mid_long_thigh, right_big_mid_thigh, right_low_right_thigh, right_low_left_thigh, left_top_low_thigh, left_top_top_thigh, left_mid_long_thigh, left_big_mid_thigh, left_low_left_thigh, left_low_right_thigh ]}

# %%
from PIL import Image, ImageDraw



# Load the image
image = Image.open(image_path)

# Create a draw object
draw = ImageDraw.Draw(image, 'RGBA')

def color_image(lista, isprimary):
    if isprimary:
        color = 255
    else:
        color = 125
    for body_part in lista:
        coordinates_list = body_dict[body_part]
        for cords in coordinates_list:
            # Convert coordinates to integer tuples
            polygon_coords = [(int(x), int(y)) for x, y in cords]
            fill_color = (color, 0, 0, 125)  # 128 is 50% transparency (255 is fully opaque, 0 is fully transparent)
            # Draw the polygon with specified fill and outline colors
            draw.polygon(polygon_coords, outline='red', fill=fill_color)
            

color_image(primary, isprimary= True)
color_image(secondary, isprimary= False)

# Save or display the image
image.save(output_image_path)
image.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Define our imshow function
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
import os

os.getcwd()
os.chdir('c:\\Users\\MikolajPawlak\\Documents\\GitHub\\Public-projects\\Hevy Workout App Analytics Dashboard')

# %%
# Load the image with a white background
image = cv2.imread('human_body.jpg')
#imshow(title = "Image", image = image, size = s)
# Convert image to RGBA
image_rgba = cv2.cvtColor(image, cv2.COLOR_BGR2BGRA)
s = 6

# Define the lower and upper bounds for white color
for x in [250]:
    lower_white = np.array([x, x, x, 0], dtype=np.uint8)
    upper_white = np.array([255, 255, 255, 255], dtype=np.uint8)

    # Create a mask to identify white areas
    mask = cv2.inRange(image_rgba, lower_white, upper_white)

    # Set white areas to be transparent
    image_rgba[mask == 255] = [0, 0, 0, 0]

    # Save the image with transparency
    cv2.imwrite('human_body_transparent.png', image_rgba)

    imshow(title = f"Image x = {x}", image = image_rgba, size = s)
    
print("Background changed to transparent.")
# Out:
# Background changed to transparent.

# %%
# Convert image to RGBA
image_rgba2 = cv2.cvtColor(image, cv2.COLOR_BGR2BGRA)

# Define the lower and upper bounds for near-white colors
lower_white = np.array([200, 200, 200], dtype=np.uint8)
upper_white = np.array([255, 255, 255], dtype=np.uint8)

# Create a mask to identify white areas
mask = cv2.inRange(image, lower_white, upper_white)

# Use a Gaussian blur to smooth the mask edges
#blur_strength = 5
#mask = cv2.GaussianBlur(mask, (blur_strength, blur_strength), 0)

# Invert the mask to make the object opaque and the background transparent
mask_inv = cv2.bitwise_not(mask)

alpha_factor = 1
# Normalize the mask to use it as an alpha channel (0-1 range)
alpha = mask_inv.astype(float) / 255.0 * alpha_factor

# Apply the alpha channel to the RGBA image
for c in range(3):  # Iterate over the color channels
    image_rgba2[:, :, c] = image_rgba2[:, :, c] * alpha

# Set the alpha channel
image_rgba2[:, :, 3] = mask_inv

# Save the smoothed, transparent background image
imshow(title = f"Image x = {250}", image = image_rgba2, size = s)
cv2.imwrite('human_body_transparent_smooth.png', image_rgba2)
# Out:
# True
